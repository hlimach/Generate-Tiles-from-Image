# %%
import sys
sys.path.append('.')

from utils import *

# %matplotlib inline

# %%
imgs_dict = load_pngs_dict('./images')
# Out:
# Dict created!
# Loaded 1 images.

# %%
# visualize tiles created by grid
fig = plt.figure(figsize=(22, 18))

for key in imgs_dict:
    img, tiles, mask = get_tiles_by_grid(imgs_dict[key], r=10, c=12)
    plt.imshow(cv2.cvtColor(np.concatenate((img, mask), axis=1), cv2.COLOR_BGR2RGB))
    plt.show()

# %%
# visualize tiles created by pixel size
fig = plt.figure(figsize=(22, 18))

for key in imgs_dict:
    img, tiles, mask = get_tiles_by_pixels(imgs_dict[key], h=100, w=100)
    plt.imshow(cv2.cvtColor(np.concatenate((img, mask), axis=1), cv2.COLOR_BGR2RGB))
    plt.show()
